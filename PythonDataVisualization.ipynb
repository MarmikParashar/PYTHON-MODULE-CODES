# %%
# Working with Matplot Lib

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# mpl.__version__

# Simple Graph Plat

# %%
xpoints = np.array([0,23,44,61,86,100])

# %%
xpoints
# Out:
# array([  0,  23,  44,  61,  86, 100])

# %%
ypoints = np.array([11,32,56,77,93,111])

# %%
ypoints
# Out:
# array([ 11,  32,  56,  77,  93, 111])

# %%
plt.plot(xpoints,ypoints)

# %%
# Plot using only a single axis
# Using x axis
plt.plot(xpoints)

# %%
# Scatter Plot
# The Age and Speed of 13 Cars

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

# %%
# Comparing Two Plots
plt.scatter(x, y, color="Red")

# %%
# # method to cahnge the color in the plot

# %%
# Bar Graphs 
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
# Horizontal Bar graph
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
# Change the width of Bars 
plt.bar(x, y, width = 0.1) # bar width
# Out:
# <BarContainer object of 4 artists>

# %%
# Mention Lables in Plot
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.grid()
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
# Marker Size 
ypoints = np.array([3, 8, 1, 10])

# %%
plt.plot(ypoints, marker = 'o')     # plot method

# %%
plt.plot(ypoints, 'o:g')            # notation and color together

# %%
plt.plot(ypoints, marker = 'o', ms = 20)  # ms to set the size of the markers

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')  # ms to set the color of the markers edge

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')  # ms to set the color of the markers face

# %%
# Adding Label and Title in Graph
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data")    # title name 
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
# Changing the font color and font style in graph lables and title
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'algerian' ,'color':'blue','size':20}
font2 = {'family':'serif','color':'red','size':15}

plt.title("Sports Watch Data" , fontdict = font1)
plt.xlabel("Average Pulse" , fontdict = font2)
plt.ylabel("Calorie Burnage" , fontdict = font2)

plt.plot(x , y , color = "cyan")

# %%
# Changing the location of title in the graph

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

# %%
# Multiple graph plot by using subplot

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 1, 1)    # here 3 is the no. of partitions for no. of subplots
plt.plot(x,y,color = "Yellow")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 1, 2)
plt.plot(x,y,color = "Green")

#plot 3:
x = np.array([1, 7, 6, 3])
y = np.array([11, 20, 30, 40])

plt.subplot(3,1,3)
plt.plot(x,y,color="Red")

# %%
# Draw Pie Chart
y = np.array([35, 25, 25, 15])
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x28bf3ef2300>,
# ...
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
# Adding labels to pie chart

y = np.array([35, 25, 25, 15, 87])
mylabels = ["Apples", "Bananas", "Cherries", "Dates", "Mangos"]
plt.pie(y, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x28bf47604a0>,
# ...
#  [Text(0.9152577389808911, 0.6101665930183224, 'Apples'),
#   Text(-0.027717032514917927, 1.099650747332337, 'Bananas'),
#   Text(-0.8373460335225008, 0.7133383630116461, 'Cherries'),
#   Text(-1.099379133077631, 0.03695296677503027, 'Dates'),
#   Text(0.11988107813538763, -1.093447999268871, 'Mangos')])

# %%
# adding angles 

plt.pie(y, labels = mylabels, startangle = 120)
plt.show()

# %%
# Explode the wedge fro the pie graph

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0.1, 0.3, 0.4]

# explode is used for seprating the pie slices
plt.pie(y, labels = mylabels, explode = myexplode)
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True) 
plt.show()

# %%
# Specifying a new color for each wedge:

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["red", "yellow", "magenta", "brown"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
# adding legend in pie chart with title

y = np.array([35, 25, 25, 15])
labels = ['Walk', 'Talk', 'Sleep', 'Work']
colors = ['red', 'blue', 'green', 'yellow']

patches, texts = plt.pie(y, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
'''
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
patches , texts = plt.pie(y)
plt.legend(patches , mylabels , title = "Four Fruits:", loc = 'best')
plt.axis('equal')'''
# Out:
# '\nmylabels = ["Apples", "Bananas", "Cherries", "Dates"]\npatches , texts = plt.pie(y)\nplt.legend(patches , mylabels , title = "Four Fruits:", loc = \'best\')\nplt.axis(\'equal\')'

# %%
# To show the percentage for slices of pie chart

import numpy as np
import matplotlib.pyplot as plt
y = np.array([350, 250, 650, 150])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, autopct='%1.3f%%')
# 1.2f for the hundreds and 1.3 for thousands
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.array([50, 60, 30, 40])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, autopct='%1.1f%%')
# 1.2f for the hundreds and 1.3 for thousands
plt.show()

# %%
# Multiline Graph

import numpy as np
import matplotlib.pyplot as plt

 # set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
 edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
 edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
 edgecolor ='grey', label ='CSE')

# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],['2015', '2016', '2017', '2018', '2019'])
plt.legend()
plt.show()
