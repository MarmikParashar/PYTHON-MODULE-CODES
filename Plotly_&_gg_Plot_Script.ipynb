# %%
# Plotly

#simple line plot by uisng plotly

import plotly.express as px  
import pandas as pd
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
df
# plotting the line chart using csv file
fig = px.bar(df, x="Model", y="Price")  
# showing the plot 
fig.show()

# %%
# line chart
import plotly.express as px  
import pandas as pd
  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')

# plotting the line chart using csv file
fig = px.line(df, x="Year",y="Price")  
  
# showing the plot 
fig.show()

# %%
import plotly.express as px  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
# plotting the line chart using csv file
brand_by= df.groupby(['Brand'],as_index=False)['Model'].value_counts()
brand_by
# Out:
#      Brand        Model  count
# 0      BMW  Convertible      8
# 1      BMW    Hatchback      7
# 2      BMW        Sedan      7
# 3      BMW          Van      7
# 4      BMW        Wagon      6
# ..     ...          ...    ...
# 75  Toyota    Hatchback      6
# 76  Toyota          SUV      6
# 77  Toyota        Truck      6
# 78  Toyota  Convertible      5
# 79  Toyota        Wagon      3
#
# [80 rows x 3 columns]

# %%
px.bar(brand_by , x = 'Brand' , y = 'count' , color = "Model")

# %%
# plotting the histogram 
import plotly.express as px  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
# plotting the line chart using csv file
fig = px.histogram(df, x="Brand")  
# showing the plot 
fig.show()

# %%
# plotting the scatter chart
import plotly.express as px  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
# plotting the line chart using csv file
fig = px.scatter(df, x="Brand", y="Year")  
# showing the plot 
fig.show()

# %%
# plotting the pie chart 
import plotly.express as px  
  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
fig = px.pie(df, values="Price", names="Model")  
  
# showing the plot 
fig.show()

# %%
# plotting the Box 
import plotly.express as px  
  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
fig = px.box(df, x="Brand", y="Year")  
  
# showing the plot 
fig.show()

# %%
import plotly.express as px  
  
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')

# plotting the violin chart 
fig = px.violin(df, x="Brand") 
  
# showing the plot 
fig.show()

# %%
# Gantt chart
import plotly.figure_factory as ff  
  
# Data to be plotted 
df = [dict(Task="A", Start='2020-01-01', Finish='2009-02-02'),
    dict(Task="Job B", Start='2020-03-01', Finish='2020-11-11'),  
    dict(Task="Job C", Start='2020-08-06', Finish='2020-09-21')]  
  
# Creating the plot 
fig = ff.create_gantt(df)  
fig.show()

# %%
#3D line graph
import plotly.express as px  
  
# data to be plotted 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
# plotting the figure 
fig = px.line_3d(df, x="Brand", y="Year", z="Price", color="Brand")  
fig.show()

# %%
# plotting #D Scatterd
import plotly.express as px  
  
# Data to be plotted 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
# plotting the figure 
fig = px.scatter_3d(df, x="Brand", y="Price", z="Year", color="Model")  
  
 
fig.show()

# %%
import plotly.express as px 
# windgraph
  
# using the wind dataset 
#df = px.data.wind() 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
df1=px.data.wind()
  
fig = px.bar_polar(df, r="Model", theta="Brand", color="Price",) 
fig.show()

# %%
import plotly.express as px 
  
 # Data to be plotted 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
# plotting the figure 
fig = px.bar_polar(df, r = "Year", theta= "Model", color="Price") 
  
fig.show()

# %%
pip install plotnine
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.3 MB 1.3 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.3 MB 1.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.3 MB 1.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.3 MB 655.4 kB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.3 MB 717.5 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.3 MB 701.4 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.3 MB 581.0 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.3 MB 581.0 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.3 MB 573.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.3 MB 578.7 kB/s eta 0:00:02
# ...

# %%
# ggplot

# Basic Code for ggplot
import pandas as pd 
from plotnine import ggplot 
  
# reading dataset 
df = pd.read_csv("C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv") 
  
# passing the data to the ggplot  
# There will be blank output because axis and colm compnonet is not given
ggplot(df)

# %%
#Statistical transformations

import pandas as pd 
from plotnine import ggplot, aes, geom_col 
  
# reading dataset 
df = pd.read_csv("C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv") 
  
ggplot(df) + aes( x="Brand", y="Price") + geom_col()

# %%
# Bar Chart

import pandas as pd 
from plotnine import ggplot, aes, geom_col 
  
# reading dataset 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  # geom_col is for bar chart
ggplot(df) + aes(x="Brand", y="Year") + geom_col()

# %%
# Histogram

import pandas as pd 
from plotnine import ggplot, aes, geom_histogram 
#Geometric Objects (geoms)such as point, line, histogram, bar, boxplot, etc.
  
# reading dataset 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
  
ggplot(df) + aes(x="Brand") + geom_histogram(bins=25)

# %%
import pandas as pd 
from plotnine import ggplot, aes, geom_histogram 
#Geometric Objects (geoms)such as point, line, histogram, bar, boxplot, etc.
  
# reading dataset 
df = pd.read_csv('C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv')
#ggplot(df) + aes(x="Brand") + geom_histogram(bins=25) + coord_flip()
# Not running as coord_flip() is not working

# %%
#Themes: improving the looks of the data visualization

import pandas as pd 
import plotnine
from plotnine import ggplot, aes, facet_grid, labs, geom_col, theme_dark

# theme type: theme_classic, theme_gray, theme_light, theme_538()
# reading dataset 

df = pd.read_csv("C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv") 

plot =( 
	ggplot(df) 
	+ facet_grid() 
	+ aes(x="Model", y="Price", fill="Brand") 
	+ labs( 
		x="Model", 
		y="Price", 
	) 
	+ geom_col() + theme_dark()
	)
plot.show()

# save the plot graph
plot.save("C:\\Users\\marmi\\OneDrive\\Pictures\\themeplot.png")
# Out:
# C:\Users\marmi\anaconda3\Lib\site-packages\plotnine\ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# C:\Users\marmi\anaconda3\Lib\site-packages\plotnine\ggplot.py:607: PlotnineWarning: Filename: C:\Users\marmi\OneDrive\Pictures\themeplot.png

# %%
#draw the plot using map function

import seaborn 
import matplotlib.pyplot as plt 

# loading of a dataframe from seaborn 
df = seaborn.load_dataset('tips') 


graph = seaborn.FacetGrid(df, col ="sex", hue ="day") 
# map the above form facetgrid with some attributes 
graph.map(plt.scatter, "total_bill", "tip").add_legend() 
# show the object 
plt.show()

# %%
import seaborn 
import matplotlib.pyplot as plt 
  
df = seaborn.load_dataset('tips') 
  
graph = seaborn.FacetGrid(df, row ='smoker', col ='time') 
# map the above form facetgrid with some attributes 
graph.map(plt.hist, 'total_bill', bins = 15, color ='green') 
# The height of each bin shows how many values from that data fall into that range.
#The default value of the number of bins to be created in a histogram is 10
plt.show()

# %%
# use of plotnine from ggplot library

from plotnine import ggplot, aes, geom_point, labs, facet_grid, theme, element_text, element_rect
import pandas as pd

df = pd.read_csv("C:\\Users\\marmi\\OneDrive\\Documents\\cars_data.csv")

# %%
plot=(
    ggplot(df)+ aes(x="Model", y="Brand")
    + geom_point()
    + labs(x="Car Model", y="Brand Name")
)
plot.show()

# %%
plot = (
    ggplot(df) + aes(x="Model", y="Price")
    + geom_point()
    + facet_grid("Brand") # divide the data in subdata
    + labs(x="Model", y="Price Earned")
)
plot.show()

# %%
plot =(
   ggplot(df)+ aes(x="Model", y="Price")
    + geom_point()
    + facet_grid(cols="Year")  # didvide accordingly year of manufactuing
    + labs(x="Model", y="Annual Price")
)
plot.show()

# %%
'''plot = (
    ggplot(df)+ aes(x="Price", y="Model")
    + geom_point()
    + facet_grid("Brand", "Year")
    + labs(x="Price", y="Model")
)
plot.show()     # Not Working'''

# %%
# facet plot with reorded drv category
'''
plot =(
     ggplot(df)+ aes(x="Model", y="Brand")
    + geom_point()
    + facet_grid("Price", "Year")
    + labs(x="Model", y="Brand")
)        # Not Working
plot.show()
'''
